# %% [markdown]
# <figure>
#   <img src ='https://cdn.datafloq.com/cache/blog_pictures/878x531/choosing_the_right_web_extraction_technique.jpg' alt = 'Trulli' style = 'width:200'>
# </figure>

# %%
from bs4 import BeautifulSoup
import requests

# %%
# url extraction

url = "https://boston.craigslist.org/search/sof"
url
# Out:
# 'https://boston.craigslist.org/search/sof'

# %%
# creating response element

response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# Response [200]> means the internet connection is great ,url is working.

# %%
# extracting source code of page

data = response.text
print(data)
# Out:
# ﻿<!DOCTYPE html>
# <html class="no-js"><head>
#     <title>boston software/qa/dba/etc  jobs - craigslist</title>
#     <script type="application/ld+json" id="ld_breadcrumb_data" >
#     {"@context":"https://schema.org","itemListElement":[{"item":{"name":"boston.craigslist.org","@id":"https://boston.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"jobs","@id":"https://boston.craigslist.org/d/jobs/search/jjj"},"position":2,"@type":"ListItem"},{"item":{"name":"software","@id":"https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}
# </script>
#
#
#     <meta name="description" content="">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
#         <link rel="canonical" href="https://boston.craigslist.org/d/software-qa-dba-etc/search/sof">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
# ...

# %%
# parsing the page

soup = BeautifulSoup(data,'html.parser')

# extracting all the a tags

tags = soup.find_all('a')
tags
# Out:
# [<a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#          Android
#      </a>,
#  <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#          iOS
#      </a>,
#  <a class="header-logo" href="/" name="logoLink">CL</a>,
#  <a href="/">boston</a>,
#  <a href="https://post.craigslist.org/c/bos">post</a>,
#  <a href="https://accounts.craigslist.org/login/home">account</a>,
#  <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>,
#  <a class="to-banish-page-link" href="#">
#  <span aria-hidden="true" class="icon icon-trash red"></span>
#  <span class="banished_count">0</span>
#  <span class="discards-label"> hidden</span>
#  </a>,
#  <a class="header-logo" href="/">CL</a>,
# ...

# %%
# finding the href tags

for tag in tags:
    print(tag.get('href'))
# Out:
# https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile
# https://apps.apple.com/us/app/craigslist/id1336642410
# /
# /
# https://post.craigslist.org/c/bos
# https://accounts.craigslist.org/login/home
# #
# #
# /
# https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fboston%2Ecraigslist%2Eorg%2Fd%2Fsoftware%2Dqa%2Ddba%2Detc%2Fsearch%2Fsof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof?sort=date&
#
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
#
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7314476107.html
# https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7314476107.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7314475974.html
# https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7314475974.html
# #
# ...

# %%
#  parsing titles with html elements
titles =soup.find_all("a",{"class":"result-title"})
titles
# Out:
# [<a class="result-title hdrlnk" data-id="7314476107" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7314476107.html" id="postid_7314476107">Data Science Fellowship</a>,
#  <a class="result-title hdrlnk" data-id="7314475974" href="https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7314475974.html" id="postid_7314475974">Product Management Fellowship</a>,
#  <a class="result-title hdrlnk" data-id="7314475787" href="https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7314475787.html" id="postid_7314475787">Software Engineering Fellowship</a>,
#  <a class="result-title hdrlnk" data-id="7314306065" href="https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7314306065.html" id="postid_7314306065">Software Engineer</a>,
# ...

# %%
# scraping titles
for title in titles:
    print(title.text)
# Out:
# Data Science Fellowship
# Product Management Fellowship
# Software Engineering Fellowship
# Software Engineer
# IT Systems Analyst
# Back-End Developer
# Full Stack Developer
# Software Engineer
# React/React Native Frontend Developer (Remote, Contract)
# Contractor Backend Developer
# Software Engineer
# Data Science Fellowship
# Product Management Fellowship
# Software Engineering Fellowship
# Software Engineer
# Sr. Software Engineer
# Sr. Software Engineer
# Entry Level - Software Developer
# Software Engineer
# Best In-Demand IT Skills & Job Training Program
# Earn $$$ from home - Pixel phone tester
# print On-site VR Device Testing
# Data Science Fellowship
# Product Management Fellowship
# Software Engineering Fellowship
# Certified Encompass Developer/Programmer
# Software Engineer
# Xamarine Software Developer
# Software Engineer
# Software Engineer
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# ...

# %% [markdown]
# as you can see one , shows titles within html ekements the other extracts titles alone

# %% [markdown]
# <h> Web scrapping addresses<h>

# %%
# sidentifying addresses
adresses= soup.find_all("span",{"class":"result-hood"})
adresses
# Out:
# [<span class="result-hood"> (Remote)</span>,
#  <span class="result-hood"> (Beverly)</span>,
#  <span class="result-hood"> (Cambridge)</span>,
#  <span class="result-hood"> (Cambridge)</span>,
#  <span class="result-hood"> (Remote)</span>,
#  <span class="result-hood"> (Remote)</span>,
#  <span class="result-hood"> (Remote)</span>,
#  <span class="result-hood"> (boston: northwest/merrimack)</span>,
#  <span class="result-hood"> (boston: northwest/merrimack)</span>,
#  <span class="result-hood"> (Remote)</span>,
#  <span class="result-hood"> (Framingham)</span>,
#  <span class="result-hood"> (Boston)</span>,
#  <span class="result-hood"> (Remote)</span>,
#  <span class="result-hood"> (Newton Highlands)</span>,
#  <span class="result-hood"> (Remote)</span>,
#  <span class="result-hood"> (Remote)</span>]

# %%
# obtaining addresses from tags
for adress in adresses:
    print(adress.text)
# Out:
#  (Remote)
#  (Beverly)
#  (Cambridge)
#  (Cambridge)
#  (Remote)
#  (Remote)
#  (Remote)
#  (boston: northwest/merrimack)
#  (boston: northwest/merrimack)
#  (Remote)
#  (Framingham)
#  (Boston)
#  (Remote)
#  (Newton Highlands)
#  (Remote)
#  (Remote)

# %% [markdown]
# Just like the precedent title so does it happen to addresses.

# %%
jobs = soup.find_all('div',{'class':'result-info'})
jobs
# Out:
# [<div class="result-info">
#  <span class="icon icon-star" role="button">
#  <span class="screen-reader-text">favorite this post</span>
#  </span>
#  <time class="result-date" datetime="2021-04-29 15:38" title="Thu 29 Apr 03:38:06 PM">Apr 29</time>
#  <h3 class="result-heading">
#  <a class="result-title hdrlnk" data-id="7314476107" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7314476107.html" id="postid_7314476107">Data Science Fellowship</a>
#  </h3>
#  <span class="result-meta">
#  <span class="result-tags">
#  </span>
#  <span class="banish icon icon-trash" role="button">
#  <span class="screen-reader-text">hide this posting</span>
#  </span>
#  <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
#  <a class="restore-link" href="#">
#  <span class="restore-narrow-text">restore</span>
#  <span class="restore-wide-text">restore this posting</span>
#  </a>
#  </span>
#  </div>, <div class="result-info">
# ...

# %% [markdown]
# <h> Extracting Job details wrapper </h>

# %%
for job in jobs:
    title = job.find('a',{'class':'result-title'}).text
    location_tag = job.find('span',{'class':'result-hood'})
    location = location_tag.text[2:-1] if location_tag else "N/A"
    date = job.find('time',{'class':'result-date'}).text
    link = job.find('a',{'class':'result-title'}).get('href')
    


    print('Job Title:', title, '\nLocation', location, '\nDate:', date, '\nLink:', link, '\n---')
# Out:
# Job Title: Data Science Fellowship
# Location N/A
# Date: Apr 29
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7314476107.html
# ---
# Job Title: Product Management Fellowship
# Location N/A
# Date: Apr 29
# Link: https://boston.craigslist.org/gbs/sof/d/boston-product-management-fellowship/7314475974.html
# ---
# Job Title: Software Engineering Fellowship
# Location N/A
# Date: Apr 29
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7314475787.html
# ---
# Job Title: Software Engineer
# Location Remote
# Date: Apr 29
# Link: https://boston.craigslist.org/gbs/sof/d/andover-software-engineer/7314306065.html
# ---
# Job Title: IT Systems Analyst
# Location Beverly
# Date: Apr 28
# Link: https://boston.craigslist.org/nos/sof/d/beverly-it-systems-analyst/7313807037.html
# ---
# Job Title: Back-End Developer
# Location Cambridge
# Date: Apr 27
# ...

# %% [markdown]
# <h> Extracting Job description page<h>

# %%
for job in jobs:
    title = job.find('a',{'class':'result-title'}).text
    location_tag = job.find('span',{'class':'result-hood'})
    location = location_tag.text[2:-1] if location_tag else "N/A"
    date = job.find('time', {'class': 'result-date'}).text
    link = job.find('a', {'class': 'result-title'}).get('href')
    job_response = requests.get(link)
    job_data = job_response.text
    job_soup = BeautifulSoup(job_data, 'html.parser')
    job_description = job_soup.find('section',{'id':'postingbody'}).text
    job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
    job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
    
    print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
# Out:
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Apr 29
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7314476107.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting ok
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# ...

# %% [markdown]
# <h> Crawling and scraping multiple web pages<h>

# %%
url = "https://boston.craigslist.org/search/npo"


job_no = 0
while True:
    
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data,'html.parser')
    jobs = soup.find_all('div',{'class':'result-info'})
    
    for job in jobs:
        title = job.find('a',{'class':'result-title'}).text
        location_tag = job.find('span',{'class':'result-hood'})
        location = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find('time', {'class': 'result-date'}).text
        link = job.find('a', {'class': 'result-title'}).get('href')
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_description = job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
        job_no +=1
        print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url= 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
        
print("Total Jobs:", job_no)
# Out:
# Streaming output truncated to the last 5000 lines.
# •	Understanding of Sensory Integration Challenges
# •	Ability to perform physical tasks such as lifting and providing assistance with mobility
# •	Current CPR, First Aid, Human Rights certification. Training will be provided upon hire.
#
# The Shared Living Collaborative strives to create an agency culture characterized by ownership and a strong sense of community, facilitating flexibility and a mutual responsibility necessary to provide holistic supports to children and adults resulting in an enviable quality of life for all.
# While individual job descriptions may outline general and specific tasks, it is the desire and willingness of Employees and Providers to be flexible, invest in, and work as an integral part of our agency team that makes our agency truly extraordinary.
# Please reply by e-mail to request an application.
#
# ---
# Job Title: Residential LPN (Licensed Practical Nurse)
# Location: Braintree
# Date: Apr 26
# ...

# %% [markdown]
# <h> Saving data into csv<h>

# %%
# Create a dictionary
v = {'key':'value'}
print(v)
# Out:
# {'key': 'value'}

# %%
# Update the dictionary
v['new key'] = 'new value'
print(v)
# Out:
# {'key': 'value', 'new key': 'new value'}

# %%
import pandas as pd

npo_jobs = {}
job_no = 0
while True:
    
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data,'html.parser')
    jobs = soup.find_all('div',{'class':'result-info'})
    
    for job in jobs:
        
        title = job.find('a',{'class':'result-title'}).text
        location_tag = job.find('span',{'class':'result-hood'})
        location = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find('time', {'class': 'result-date'}).text
        link = job.find('a', {'class': 'result-title'}).get('href')
        
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_description = job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
        
        job_no+=1
        npo_jobs[job_no] = [title, location, date, link, job_attributes, job_description]
        
        
#       print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
        
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url= 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
        
print("Total Jobs:", job_no)
npo_jobs_df = pd.DataFrame.from_dict(npo_jobs, orient = 'index', columns = ['Job Title','Location','Date', 'Link', 'Job Attributes', 'Job Description'])
# Out:
# Total Jobs: 7

# %%
import pandas as pd


url = "https://boston.craigslist.org/search/npo"


# Create a dictionary
d = {'key':'value'}
print(d)


# Update the dictionary
d['new key'] = 'new value'
print(d)


npo_jobs = {}
job_no = 0
while True:
    
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data,'html.parser')
    jobs = soup.find_all('div',{'class':'result-info'})
    
    for job in jobs:
        
        title = job.find('a',{'class':'result-title'}).text
        location_tag = job.find('span',{'class':'result-hood'})
        location = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find('time', {'class': 'result-date'}).text
        link = job.find('a', {'class': 'result-title'}).get('href')
        
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_description = job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
        
        job_no+=1
        npo_jobs[job_no] = [title, location, date, link, job_attributes, job_description]
        
        
#       print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
        
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url= 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
        
print("Total Jobs:", job_no)
npo_jobs_df = pd.DataFrame.from_dict(npo_jobs, orient = 'index', columns = ['Job Title','Location','Date', 'Link', 'Job Attributes', 'Job Description'])
# Out:
# {'key': 'value'}
# {'key': 'value', 'new key': 'new value'}
# https://boston.craigslist.org/d/nonprofit/search/npo?s=120
# Total Jobs: 127

# %%
# overview of data
npo_jobs_df.head()
# Out:
#                                            Job Title  ...                                    Job Description
# 1                       Housing Case Manager FT (EA)  ...  \n\nQR Code Link to This Post\n\n\nRole Purpos...
# 2           Medical Technologist II - Flow Cytometry  ...  \n\nQR Code Link to This Post\n\n\nAt Boston C...
# 3               Phlebotomist II - Norwood - 40 hours  ...  \n\nQR Code Link to This Post\n\n\nAt Boston C...
# 4  Phlebotomist II -Location: 2 Brookline Place(8...  ...  \n\nQR Code Link to This Post\n\n\nAt Boston C...
# 5                 Program Staff Scattered Sites-Lynn  ...  \n\nQR Code Link to This Post\n\n\nBroad Stree...
#
# [5 rows x 6 columns]

# %%
#saving data to my google drive
 

npo_jobs_df.to_csv('/content/drive/MyDrive/web scraping/npo_jobs.csv')
